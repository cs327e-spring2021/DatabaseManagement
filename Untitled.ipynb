# %%
# %%bigquery
#   select * from datamart.title where averageRating is not null limit 10
# Out:
#       tconst     titleType                                   primaryTitle  \
# 0  tt2219128     videoGame                                   Chûka Taisen
# 1  tt8860862       tvShort                Kak lisy s kurami podruzhilis..
# 2  tt4616150       tvShort                                  First Whinter
# 3  tt0168494       tvShort                                 Beanstalk Jack
# 4  tt0246644     tvSpecial  George Carlin: What Am I Doing in New Jersey?
# 5  tt0364891  tvMiniSeries                               La traccia verde
# 6  tt0083487  tvMiniSeries                                    Ta den ring
# 7  tt0081543       tvShort                               Spaced Out Bunny
# 8  tt0816227  tvMiniSeries                                    Jok gor juk
# 9  tt0276704  tvMiniSeries              Molière pour rire et pour pleurer
#
#                                    originalTitle  isAdult  startYear  endYear  \
# ...
